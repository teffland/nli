# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb
sb.set()
plt.rcParams['figure.figsize'] = (12,9)

# %%
import numpy as np
import numpy.random as npr
import chainer as ch
import chainer.functions as F
import chainer.links as L
import chainer.training.extensions

# %%
from dataset import load_data
from vocab import Vocab
from word_vectors import get_pretrained_vectors
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-2ad69754bdea> in <module>()
#       1 from dataset import load_data
# ----> 2 from vocab import Vocab
#       3 from word_vectors import get_pretrained_vectors
#
# ImportError: No module named vocab

# %%
train_data, dev_data = load_data("data/multinli_0.9/", 
                                 matched=True, 
                                 genres=[],#['government'],
                                 drop_confused=True, 
                                 lowercase=True)
print("{} training examples, {} dev examples".format(len(train_data), len(dev_data)))

# %%
vocab = Vocab(min_count=1)
vocab.add([ token for datum in train_data for token in datum['h'] ])
vocab.add([ token for datum in train_data for token in datum['p'] ])
vocab.add([ token for datum in dev_data for token in datum['h'] ])
vocab.add([ token for datum in dev_data for token in datum['p'] ])
vocab.drop_infrequent()

# %%
token_embeddings = get_pretrained_vectors(vocab, 'data/word_vectors/glove.6B.300d.txt', trim=False)

# %%
class_vocab = Vocab([ datum['c'] for datum in train_data ],
                    min_count=0,
                    pad_token=None,
                    unk_token=None)

# %%
class CBOW(ch.Chain):
    def __init__(self, embeddings):
        super(CBOW, self).__init__(
            token_embeddings=L.EmbedID(embeddings.shape[0], embeddings.shape[1], embeddings)
        )
    
    def __call__(self, xs):
        """ Sum up embeddings for x """
        xs_vecs = [ self.token_embeddings(x) for x in xs ]
        xs_vec = [ F.sum(x_vecs, axis=0) for x_vecs in xs_vecs ]
        return xs_vec
    
class NLIPredictor(ch.Chain):
    """ Convert pairs of premise and hypothesis sentences (tokenized) into an
    entailment class distribution.
    
    """
    def __init__(self, vocab, h_model, c_model, p_model=None):
        super(NLIPredictor, self).__init__()
        self.add_link('h_model', h_model)
        if p_model is not None: 
            self.add_link('p_model', p_model)
        else:
            self.p_model = None
        self.add_link('c_model', c_model)
        self.vocab = vocab
        
    def _preprocess(self, xs, volatile):
        """ Convert a list of NLI data into token index arrays for hs and ps.
        
        These arrays are then sorted by length
        and the corresponding inverted index is also returned.
        
        This allows for chainer RNNs to handle separate sequence batches
        efficiently while restoring the order before the output.
        """
        hs_ids = [ ch.Variable(np.array(
                     [ self.vocab.idx(token) for token in x['h']], 
                   dtype=np.int32), volatile=volatile)
                   for x in xs ]
        hs_ids, hs_sort = zip(*sorted(zip(hs_ids, range(len(hs_ids))),
                                       key=lambda x:len(x[0]),
                                       reverse=True))
        ps_ids = [ ch.Variable(np.array(
                     [ self.vocab.idx(token) for token in x['p']], 
                   dtype=np.int32), volatile=volatile)
                   for x in xs ]
        ps_ids, ps_sort = zip(*sorted(zip(ps_ids, range(len(ps_ids))),
                                       key=lambda x:len(x[0]),
                                       reverse=True))
        return hs_ids, hs_sort, ps_ids, ps_sort
    
    def __call__(self, batch, volatile='off'):
        # convert to ids and sort by descending length
        hs_ids, hs_sort, ps_ids, ps_sort = self._preprocess(batch, volatile)
        
        # get sentence representations 
        hs_reps = self.h_model(hs_ids)
        ps_reps = self.p_model(ps_ids) if self.p_model else self.h_model(ps_ids)
        
        # put them back in original order
        hs_reps = [ hs_reps[i] for i in hs_sort ]
        ps_reps = [ ps_reps[i] for i in ps_sort ]
        
        return self.c_model(hs_reps, ps_reps)
    
class MLP(ch.Chain):
    def __init__(self, h_sizes, fs=[]):
        super(MLP, self).__init__()
        
        # create affine transforms
        self.hs = []
        for i, h_size in enumerate(h_sizes):
            h = L.Linear(None, h_size) # input size is inferred
            self.hs.append(h)
            self.add_link('h_{}'.format(i), h)
        
        # register nonlinearities (as chainer callables)
        if fs:
            assert len(fs) == (len(self.hs)-1), "Must have one less activation than affine transforms"
            self.fs = fs
        else:
            self.fs = [ F.relu for _ in range(len(self.hs)-1) ]
            
    def __call__(self, x):
        z = x
        for i, f in enumerate(self.fs):
            z = f(self.hs[i](z))
        return self.hs[-1](z)
    
class EntailmentConcatModel(ch.Chain):
    def __init__(self, classifier):
        super(EntailmentConcatModel, self).__init__(
            classifier=classifier
        )
    
    def __call__(self, hs, ps):
        # convert to matrices if needed
        if type(hs) is list:
            hs = F.vstack(hs)
        if type(ps) is list:
            ps = F.vstack(ps)
            
        # combine them
        hps = F.hstack([hs, ps])
        return self.classifier(hps)
    
class NLILossModel(ch.Chain):
    """ Wraps NLI """
    def __init__(self, class_vocab, nli_predictor):
        super(NLILossModel, self).__init__(nli_predictor=nli_predictor)
        self.class_vocab = class_vocab
        self.loss = None,
        self.accuracy = -1e5
        self.precision = -1e5
        self.recall = -1e5
        self.f1 = -1e5
        self.support = -1e5
#         ch.reporter.report({'precision':self.precision,
#                             'recall':self.recall,
#                             'f1': self.f1,
#                             'support':self.support}, self)
        
    def __call__(self, batch, volatile='off'):
        c_true = ch.Variable(np.array(
                    [ self.class_vocab.idx(x['c']) for x in batch ], dtype=np.int32
                 ), volatile=volatile)
        c_pred = self.nli_predictor(batch, volatile=volatile)
        self.loss = F.softmax_cross_entropy(c_pred, c_true)
        ch.reporter.report({'loss':self.loss}, self)
        self.accuracy = F.accuracy(c_pred, c_true)
        ch.reporter.report({'accuracy':self.accuracy}, self)
        self.precision, self.recall, self.f1, self.support = F.classification_summary(c_pred, c_true)
        ch.reporter.report({'precision':self.precision.data.mean(),
                            'recall':self.recall.data.mean(),
                            'f1': self.f1.data.mean(),
                            'support':self.support.data.mean()}, self)
        return self.loss

# %%
cbow = CBOW(token_embeddings)
c_model = EntailmentConcatModel(MLP([100,100,3]))
predictor = NLIPredictor(vocab, cbow, c_model)
loss_model = NLILossModel(class_vocab, predictor)

# %%
optimizer = ch.optimizers.Adam()
optimizer.setup(loss_model)

# %%
class PassThroughUpdater(ch.training.StandardUpdater):
    """ An implementation of an updater that doesn't assume 
    the downstream model will receive a tuple or dict of chainer variables.
    
    It leaves the preprocessing of a batch of data up to the first component
    of the downstream model. It does NOT use the `converter` argument.
    """
    def update_core(self):
        batch = self._iterators['main'].next()
        optimizer = self._optimizers['main']
        loss_func = self.loss_func or optimizer.target
        optimizer.update(loss_func, batch)
        
import copy
class PassThroughEvaluator(ch.training.extensions.Evaluator):
    """ An implementation of an evaluator that doesn't assume 
    the downstream model will receive a tuple or dict of chainer variables.
    
    It leaves the preprocessing of a batch of data up to the first component
    of the downstream model. It does NOT use the `converter` argument.
    """
    def evaluate(self):
        """Evaluates the model and returns a result dictionary.

        This method runs the evaluation loop over the validation dataset. It
        accumulates the reported values to :class:`~chainer.DictSummary` and
        returns a dictionary whose values are means computed by the summary.

        Users can override this method to customize the evaluation routine.

        Returns:
            dict: Result dictionary. This dictionary is further reported via
                :func:`~chainer.report` without specifying any observer.

        """
        iterator = self._iterators['main']
        target = self._targets['main']
        eval_func = self.eval_func or target

        if self.eval_hook:
            self.eval_hook(self)
        it = copy.copy(iterator)
        summary = ch.reporter.DictSummary()

        for batch in it:
            observation = {}
            with ch.reporter.report_scope(observation):
                eval_func(batch, volatile='on')
            summary.add(observation)

        return summary.compute_mean()

# %%
batch_size = 100
train_iter = ch.iterators.SerialIterator(train_data, batch_size, shuffle=True, repeat=True)
dev_iter = ch.iterators.SerialIterator(dev_data, batch_size, shuffle=False, repeat=False)

# %%
updater = PassThroughUpdater(train_iter, optimizer)
trainer = ch.training.Trainer(updater, (10, 'epoch'), out='result')
trainer.extend(PassThroughEvaluator(dev_iter, loss_model))
trainer.extend(ch.training.extensions.LogReport((1,'epoch')))
trainer.extend(ch.training.extensions.PrintReport([
    'epoch', 'main/accuracy', 'main/precision', 'main/recall', 'main/f1', 'main/support',
    'validation/main/accuracy', 'validation/main/precision', 'validation/main/recall', 
    'validation/main/f1', 'validation/main/support']))
trainer.extend(ch.training.extensions.ProgressBar())
trainer.extend(ch.training.extensions.snapshot(
    trigger=ch.training.triggers.MaxValueTrigger('validation/main/f1', (1,'epoch'))
))

# %%
trainer.run()
# Out:
# epoch       main/accuracy  main/precision  main/recall  main/f1     main/support  validation/main/accuracy  validation/main/precision  validation/main/recall  validation/main/f1  validation/main/support
# /Users/thomaseffland/.virtualenvs/research/lib/python2.7/site-packages/chainer/functions/evaluation/classification_summary.py:15: RuntimeWarning: invalid value encountered in true_divide
#   (beta_square * precision + recall)).astype(precision.dtype)
#      total [..................................................]  0.25%
# this epoch [#.................................................]  2.55%
#        100 iter, 0 epoch / 10 epochs
#        inf iters/sec. Estimated time to finish: 0:00:00.
#      total [..................................................]  0.51%
# this epoch [##................................................]  5.09%
#        200 iter, 0 epoch / 10 epochs
#    0.10501 iters/sec. Estimated time to finish: 4 days, 7:21:05.315332.
# /Users/thomaseffland/.virtualenvs/research/lib/python2.7/site-packages/chainer/functions/evaluation/classification_summary.py:62: RuntimeWarning: invalid value encountered in true_divide
#   precision = tp / relevant
#      total [..................................................]  0.76%
# this epoch [###...............................................]  7.64%
#        300 iter, 0 epoch / 10 epochs
#    0.10707 iters/sec. Estimated time to finish: 4 days, 5:06:04.479383.
#      total [..................................................]  1.02%
# this epoch [#####.............................................] 10.19%
#        400 iter, 0 epoch / 10 epochs
#    0.10778 iters/sec. Estimated time to finish: 4 days, 4:10:53.296206.
#      total [..................................................]  1.27%
# this epoch [######............................................] 12.73%
#        500 iter, 0 epoch / 10 epochs
#    0.10817 iters/sec. Estimated time to finish: 4 days, 3:33:30.513343.
#      total [..................................................]  1.53%
# this epoch [#######...........................................] 15.28%
#        600 iter, 0 epoch / 10 epochs
#    0.10836 iters/sec. Estimated time to finish: 4 days, 3:07:42.446352.
#      total [..................................................]  1.78%
# this epoch [########..........................................] 17.83%
#        700 iter, 0 epoch / 10 epochs
#    0.10853 iters/sec. Estimated time to finish: 4 days, 2:43:12.254692.
#      total [#.................................................]  2.04%
# this epoch [##########........................................] 20.37%
#        800 iter, 0 epoch / 10 epochs
#     0.1086 iters/sec. Estimated time to finish: 4 days, 2:24:00.026392.
#      total [#.................................................]  2.29%
# this epoch [###########.......................................] 22.92%
#        900 iter, 0 epoch / 10 epochs
#    0.10864 iters/sec. Estimated time to finish: 4 days, 2:06:35.771337.
#      total [#.................................................]  2.55%
# this epoch [############......................................] 25.46%
#       1000 iter, 0 epoch / 10 epochs
#    0.10864 iters/sec. Estimated time to finish: 4 days, 1:51:11.268045.
#      total [#.................................................]  2.80%
# this epoch [##############....................................] 28.01%
#       1100 iter, 0 epoch / 10 epochs
#    0.10863 iters/sec. Estimated time to finish: 4 days, 1:36:31.367633.
#      total [#.................................................]  3.06%
# this epoch [###############...................................] 30.56%
#       1200 iter, 0 epoch / 10 epochs
#    0.10858 iters/sec. Estimated time to finish: 4 days, 1:23:46.265674.
#      total [#.................................................]  3.31%
# this epoch [################..................................] 33.10%
#       1300 iter, 0 epoch / 10 epochs
#    0.10851 iters/sec. Estimated time to finish: 4 days, 1:12:00.224811.
#      total [#.................................................]  3.57%
# this epoch [#################.................................] 35.65%
#       1400 iter, 0 epoch / 10 epochs
#    0.10843 iters/sec. Estimated time to finish: 4 days, 1:00:48.371660.
#      total [#.................................................]  3.82%
# this epoch [###################...............................] 38.20%
#       1500 iter, 0 epoch / 10 epochs
#    0.10833 iters/sec. Estimated time to finish: 4 days, 0:50:55.234475.
#      total [##................................................]  4.07%
# this epoch [####################..............................] 40.74%
#       1600 iter, 0 epoch / 10 epochs
#    0.10823 iters/sec. Estimated time to finish: 4 days, 0:41:01.075135.
#      total [##................................................]  4.33%
# this epoch [#####################.............................] 43.29%
#       1700 iter, 0 epoch / 10 epochs
#    0.10811 iters/sec. Estimated time to finish: 4 days, 0:31:51.145528.
#      total [##................................................]  4.58%
# this epoch [######################............................] 45.84%
#       1800 iter, 0 epoch / 10 epochs
#      0.108 iters/sec. Estimated time to finish: 4 days, 0:22:15.003091.
#      total [##................................................]  4.84%
# this epoch [########################..........................] 48.38%
#       1900 iter, 0 epoch / 10 epochs
#    0.10789 iters/sec. Estimated time to finish: 4 days, 0:12:37.768720.
#      total [##................................................]  5.09%
# this epoch [#########################.........................] 50.93%
#       2000 iter, 0 epoch / 10 epochs
#     0.1078 iters/sec. Estimated time to finish: 4 days, 0:02:07.524544.
#      total [##................................................]  5.35%
# this epoch [##########################........................] 53.48%
#       2100 iter, 0 epoch / 10 epochs
#    0.10771 iters/sec. Estimated time to finish: 3 days, 23:51:40.545403.
#      total [##................................................]  5.60%
# this epoch [############################......................] 56.02%
#       2200 iter, 0 epoch / 10 epochs
#    0.10762 iters/sec. Estimated time to finish: 3 days, 23:40:46.193928.
#      total [##................................................]  5.86%
# this epoch [#############################.....................] 58.57%
#       2300 iter, 0 epoch / 10 epochs
#    0.10754 iters/sec. Estimated time to finish: 3 days, 23:29:26.142774.
#      total [###...............................................]  6.11%
# this epoch [##############################....................] 61.12%
#       2400 iter, 0 epoch / 10 epochs
#    0.10745 iters/sec. Estimated time to finish: 3 days, 23:18:48.124065.
#      total [###...............................................]  6.37%
# this epoch [###############################...................] 63.66%
#       2500 iter, 0 epoch / 10 epochs
#    0.10737 iters/sec. Estimated time to finish: 3 days, 23:07:27.436951.
#      total [###...............................................]  6.62%
# this epoch [#################################.................] 66.21%
#       2600 iter, 0 epoch / 10 epochs
#    0.10729 iters/sec. Estimated time to finish: 3 days, 22:56:24.340752.
#      total [###...............................................]  6.88%
# this epoch [##################################................] 68.75%
#       2700 iter, 0 epoch / 10 epochs
#    0.10721 iters/sec. Estimated time to finish: 3 days, 22:45:03.774277.
#      total [###...............................................]  7.13%
# this epoch [###################################...............] 71.30%
#       2800 iter, 0 epoch / 10 epochs
#    0.10713 iters/sec. Estimated time to finish: 3 days, 22:33:37.581173.
#      total [###...............................................]  7.38%
# this epoch [####################################..............] 73.85%
#       2900 iter, 0 epoch / 10 epochs
#    0.10706 iters/sec. Estimated time to finish: 3 days, 22:21:48.719476.
#      total [###...............................................]  7.64%
# this epoch [######################################............] 76.39%
#       3000 iter, 0 epoch / 10 epochs
#    0.10699 iters/sec. Estimated time to finish: 3 days, 22:09:50.566830.
#      total [###...............................................]  7.89%
# this epoch [#######################################...........] 78.94%
#       3100 iter, 0 epoch / 10 epochs
#    0.10693 iters/sec. Estimated time to finish: 3 days, 21:57:50.301514.
#      total [####..............................................]  8.15%
# this epoch [########################################..........] 81.49%
#       3200 iter, 0 epoch / 10 epochs
#    0.10687 iters/sec. Estimated time to finish: 3 days, 21:45:25.979037.
#      total [####..............................................]  8.40%
# this epoch [##########################################........] 84.03%
#       3300 iter, 0 epoch / 10 epochs
#     0.1068 iters/sec. Estimated time to finish: 3 days, 21:33:06.208127.
#      total [####..............................................]  8.66%
# this epoch [###########################################.......] 86.58%
#       3400 iter, 0 epoch / 10 epochs
#    0.10674 iters/sec. Estimated time to finish: 3 days, 21:20:38.182046.
#      total [####..............................................]  8.91%
# this epoch [############################################......] 89.13%
#       3500 iter, 0 epoch / 10 epochs
#    0.10669 iters/sec. Estimated time to finish: 3 days, 21:08:00.184323.
#      total [####..............................................]  9.17%
# this epoch [#############################################.....] 91.67%
#       3600 iter, 0 epoch / 10 epochs
#    0.10664 iters/sec. Estimated time to finish: 3 days, 20:55:00.650165.
#      total [####..............................................]  9.42%
# this epoch [###############################################...] 94.22%
#       3700 iter, 0 epoch / 10 epochs
#    0.10659 iters/sec. Estimated time to finish: 3 days, 20:42:05.515647.
#      total [####..............................................]  9.68%
# this epoch [################################################..] 96.77%
#       3800 iter, 0 epoch / 10 epochs
#    0.10653 iters/sec. Estimated time to finish: 3 days, 20:29:11.296014.
#      total [####..............................................]  9.93%
# this epoch [#################################################.] 99.31%
#       3900 iter, 0 epoch / 10 epochs
#    0.10648 iters/sec. Estimated time to finish: 3 days, 20:16:26.241087.
# 1
#      total [#####.............................................] 10.19%
# this epoch [..................................................]  1.86%
#       4000 iter, 1 epoch / 10 epochs
#    0.10637 iters/sec. Estimated time to finish: 3 days, 20:06:22.939914.
#      total [#####.............................................] 10.44%
# this epoch [##................................................]  4.40%
#       4100 iter, 1 epoch / 10 epochs
#    0.10633 iters/sec. Estimated time to finish: 3 days, 19:52:57.090258.
#      total [#####.............................................] 10.70%
# this epoch [###...............................................]  6.95%
#       4200 iter, 1 epoch / 10 epochs
#     0.1063 iters/sec. Estimated time to finish: 3 days, 19:38:38.016543.
#      total [#####.............................................] 10.95%
# this epoch [####..............................................]  9.50%
#       4300 iter, 1 epoch / 10 epochs
#    0.10628 iters/sec. Estimated time to finish: 3 days, 19:24:12.525909.
#      total [#####.............................................] 11.20%
# this epoch [######............................................] 12.04%
#       4400 iter, 1 epoch / 10 epochs
#    0.10626 iters/sec. Estimated time to finish: 3 days, 19:09:27.461624.
#      total [#####.............................................] 11.46%
# this epoch [#######...........................................] 14.59%
#       4500 iter, 1 epoch / 10 epochs
#    0.10624 iters/sec. Estimated time to finish: 3 days, 18:54:32.732077.
#      total [#####.............................................] 11.71%
# this epoch [########..........................................] 17.14%
#       4600 iter, 1 epoch / 10 epochs
#    0.10622 iters/sec. Estimated time to finish: 3 days, 18:39:53.965991.
#      total [#####.............................................] 11.97%
# this epoch [#########.........................................] 19.68%
#       4700 iter, 1 epoch / 10 epochs
#     0.1062 iters/sec. Estimated time to finish: 3 days, 18:25:06.365526.
#      total [######............................................] 12.22%
# this epoch [###########.......................................] 22.23%
#       4800 iter, 1 epoch / 10 epochs
#    0.10619 iters/sec. Estimated time to finish: 3 days, 18:10:19.693780.
#      total [######............................................] 12.48%
# this epoch [############......................................] 24.78%
#       4900 iter, 1 epoch / 10 epochs
#    0.10617 iters/sec. Estimated time to finish: 3 days, 17:55:25.482820.
#      total [######............................................] 12.73%
# this epoch [#############.....................................] 27.32%
#       5000 iter, 1 epoch / 10 epochs
#    0.10615 iters/sec. Estimated time to finish: 3 days, 17:40:37.003485.
#      total [######............................................] 12.99%
# this epoch [##############....................................] 29.87%
#       5100 iter, 1 epoch / 10 epochs
#    0.10614 iters/sec. Estimated time to finish: 3 days, 17:25:50.256184.
#      total [######............................................] 13.24%
# this epoch [################..................................] 32.42%
#       5200 iter, 1 epoch / 10 epochs
#    0.10612 iters/sec. Estimated time to finish: 3 days, 17:10:48.708329.
#      total [######............................................] 13.50%
# this epoch [#################.................................] 34.96%
#       5300 iter, 1 epoch / 10 epochs
#    0.10611 iters/sec. Estimated time to finish: 3 days, 16:55:42.484914.
#      total [######............................................] 13.75%
# this epoch [##################................................] 37.51%
#       5400 iter, 1 epoch / 10 epochs
#     0.1061 iters/sec. Estimated time to finish: 3 days, 16:40:38.985813.
#      total [#######...........................................] 14.01%
# this epoch [####################..............................] 40.06%
#       5500 iter, 1 epoch / 10 epochs
#    0.10608 iters/sec. Estimated time to finish: 3 days, 16:25:57.556875.
#      total [#######...........................................] 14.26%
# this epoch [#####################.............................] 42.60%
#       5600 iter, 1 epoch / 10 epochs
#    0.10605 iters/sec. Estimated time to finish: 3 days, 16:11:31.676329.
#      total [#######...........................................] 14.51%
# this epoch [######################............................] 45.15%
#       5700 iter, 1 epoch / 10 epochs
#    0.10595 iters/sec. Estimated time to finish: 3 days, 16:00:51.862687.
#      total [#######...........................................] 14.77%
# this epoch [#######################...........................] 47.69%
#       5800 iter, 1 epoch / 10 epochs
#    0.10584 iters/sec. Estimated time to finish: 3 days, 15:50:26.932264.
#      total [#######...........................................] 15.02%
# this epoch [#########################.........................] 50.24%
#       5900 iter, 1 epoch / 10 epochs
#    0.10572 iters/sec. Estimated time to finish: 3 days, 15:40:55.549187.
#      total [#######...........................................] 15.28%
# this epoch [##########################........................] 52.79%
#       6000 iter, 1 epoch / 10 epochs
#    0.10568 iters/sec. Estimated time to finish: 3 days, 15:27:08.215442.
#      total [#######...........................................] 15.53%
# this epoch [###########################.......................] 55.33%
#       6100 iter, 1 epoch / 10 epochs
#    0.10568 iters/sec. Estimated time to finish: 3 days, 15:11:23.284623.
#      total [#######...........................................] 15.79%
# this epoch [############################......................] 57.88%
#       6200 iter, 1 epoch / 10 epochs
#    0.10567 iters/sec. Estimated time to finish: 3 days, 14:55:46.972112.
#      total [########..........................................] 16.04%
# this epoch [##############################....................] 60.43%
#       6300 iter, 1 epoch / 10 epochs
#    0.10567 iters/sec. Estimated time to finish: 3 days, 14:40:13.015199.
#      total [########..........................................] 16.30%
# this epoch [###############################...................] 62.97%
#       6400 iter, 1 epoch / 10 epochs
#    0.10566 iters/sec. Estimated time to finish: 3 days, 14:24:57.145745.
#      total [########..........................................] 16.55%
# this epoch [################################..................] 65.52%
#       6500 iter, 1 epoch / 10 epochs
#    0.10565 iters/sec. Estimated time to finish: 3 days, 14:09:23.308878.
#      total [########..........................................] 16.81%
# this epoch [##################################................] 68.07%
#       6600 iter, 1 epoch / 10 epochs
#    0.10564 iters/sec. Estimated time to finish: 3 days, 13:54:09.661082.
#      total [########..........................................] 17.06%
# this epoch [###################################...............] 70.61%
#       6700 iter, 1 epoch / 10 epochs
#    0.10563 iters/sec. Estimated time to finish: 3 days, 13:38:57.951189.
#      total [########..........................................] 17.32%
# this epoch [####################################..............] 73.16%
#       6800 iter, 1 epoch / 10 epochs
#    0.10562 iters/sec. Estimated time to finish: 3 days, 13:23:49.682748.
#      total [########..........................................] 17.57%
# this epoch [#####################################.............] 75.71%
#       6900 iter, 1 epoch / 10 epochs
#     0.1056 iters/sec. Estimated time to finish: 3 days, 13:08:43.677846.
#      total [########..........................................] 17.83%
# this epoch [#######################################...........] 78.25%
#       7000 iter, 1 epoch / 10 epochs
#    0.10559 iters/sec. Estimated time to finish: 3 days, 12:53:32.349752.
#      total [#########.........................................] 18.08%
# this epoch [########################################..........] 80.80%
#       7100 iter, 1 epoch / 10 epochs
#    0.10558 iters/sec. Estimated time to finish: 3 days, 12:38:30.920902.
#      total [#########.........................................] 18.33%
# this epoch [#########################################.........] 83.35%
#       7200 iter, 1 epoch / 10 epochs
#    0.10556 iters/sec. Estimated time to finish: 3 days, 12:23:29.714220.
#      total [#########.........................................] 18.59%
# this epoch [##########################################........] 85.89%
#       7300 iter, 1 epoch / 10 epochs
#    0.10554 iters/sec. Estimated time to finish: 3 days, 12:08:43.073317.
#      total [#########.........................................] 18.84%
# this epoch [############################################......] 88.44%
#       7400 iter, 1 epoch / 10 epochs
#    0.10553 iters/sec. Estimated time to finish: 3 days, 11:53:33.285324.
#      total [#########.........................................] 19.10%
# this epoch [#############################################.....] 90.98%
#       7500 iter, 1 epoch / 10 epochs
#    0.10551 iters/sec. Estimated time to finish: 3 days, 11:38:20.877512.
#      total [#########.........................................] 19.35%
# this epoch [##############################################....] 93.53%
#       7600 iter, 1 epoch / 10 epochs
#     0.1055 iters/sec. Estimated time to finish: 3 days, 11:23:16.135311.
#      total [#########.........................................] 19.61%
# this epoch [################################################..] 96.08%
#       7700 iter, 1 epoch / 10 epochs
#    0.10548 iters/sec. Estimated time to finish: 3 days, 11:08:08.812428.
#      total [#########.........................................] 19.86%
# this epoch [#################################################.] 98.62%
#       7800 iter, 1 epoch / 10 epochs
#    0.10547 iters/sec. Estimated time to finish: 3 days, 10:52:52.897453.
# 2
#      total [##########........................................] 20.12%
# this epoch [..................................................]  1.17%
#       7900 iter, 2 epoch / 10 epochs
#    0.10546 iters/sec. Estimated time to finish: 3 days, 10:37:43.173013.
#      total [##########........................................] 20.37%
# this epoch [#.................................................]  3.72%
#       8000 iter, 2 epoch / 10 epochs
#    0.10545 iters/sec. Estimated time to finish: 3 days, 10:22:20.453794.
#      total [##########........................................] 20.63%
# this epoch [###...............................................]  6.26%
#       8100 iter, 2 epoch / 10 epochs
#    0.10544 iters/sec. Estimated time to finish: 3 days, 10:06:52.062052.
#      total [##########........................................] 20.88%
# this epoch [####..............................................]  8.81%
#       8200 iter, 2 epoch / 10 epochs
#    0.10543 iters/sec. Estimated time to finish: 3 days, 9:51:36.567153.
#      total [##########........................................] 21.14%
# this epoch [#####.............................................] 11.36%
#       8300 iter, 2 epoch / 10 epochs
#    0.10542 iters/sec. Estimated time to finish: 3 days, 9:36:13.945553.
#      total [##########........................................] 21.39%
# this epoch [######............................................] 13.90%
#       8400 iter, 2 epoch / 10 epochs
#    0.10541 iters/sec. Estimated time to finish: 3 days, 9:20:47.224719.
#      total [##########........................................] 21.64%
# this epoch [########..........................................] 16.45%
#       8500 iter, 2 epoch / 10 epochs
#     0.1054 iters/sec. Estimated time to finish: 3 days, 9:05:28.341214.
#      total [##########........................................] 21.90%
# this epoch [#########.........................................] 19.00%
#       8600 iter, 2 epoch / 10 epochs
#    0.10539 iters/sec. Estimated time to finish: 3 days, 8:50:05.221713.
#      total [###########.......................................] 22.15%
# this epoch [##########........................................] 21.54%
#       8700 iter, 2 epoch / 10 epochs
#    0.10538 iters/sec. Estimated time to finish: 3 days, 8:34:44.744258.
#      total [###########.......................................] 22.41%
# this epoch [############......................................] 24.09%
#       8800 iter, 2 epoch / 10 epochs
#    0.10538 iters/sec. Estimated time to finish: 3 days, 8:19:19.249171.
#      total [###########.......................................] 22.66%
# this epoch [#############.....................................] 26.63%
#       8900 iter, 2 epoch / 10 epochs
#    0.10536 iters/sec. Estimated time to finish: 3 days, 8:04:00.652612.
#      total [###########.......................................] 22.92%
# this epoch [##############....................................] 29.18%
#       9000 iter, 2 epoch / 10 epochs
#    0.10535 iters/sec. Estimated time to finish: 3 days, 7:48:39.029022.
#      total [###########.......................................] 23.17%
# this epoch [###############...................................] 31.73%
#       9100 iter, 2 epoch / 10 epochs
#    0.10534 iters/sec. Estimated time to finish: 3 days, 7:33:25.576723.
#      total [###########.......................................] 23.43%
# this epoch [#################.................................] 34.27%
#       9200 iter, 2 epoch / 10 epochs
#    0.10533 iters/sec. Estimated time to finish: 3 days, 7:17:58.250774.
#      total [###########.......................................] 23.68%
# this epoch [##################................................] 36.82%
#       9300 iter, 2 epoch / 10 epochs
#    0.10532 iters/sec. Estimated time to finish: 3 days, 7:02:30.320520.
#      total [###########.......................................] 23.94%
# this epoch [###################...............................] 39.37%
#       9400 iter, 2 epoch / 10 epochs
#    0.10532 iters/sec. Estimated time to finish: 3 days, 6:47:04.771778.
#      total [############......................................] 24.19%
# this epoch [####################..............................] 41.91%
#       9500 iter, 2 epoch / 10 epochs
#    0.10531 iters/sec. Estimated time to finish: 3 days, 6:31:38.343583.
#      total [############......................................] 24.45%
# this epoch [######################............................] 44.46%
#       9600 iter, 2 epoch / 10 epochs
#     0.1053 iters/sec. Estimated time to finish: 3 days, 6:16:12.056160.
#      total [############......................................] 24.70%
# this epoch [#######################...........................] 47.01%
#       9700 iter, 2 epoch / 10 epochs
#    0.10529 iters/sec. Estimated time to finish: 3 days, 6:00:42.640723.
#      total [############......................................] 24.96%
# this epoch [########################..........................] 49.55%
#       9800 iter, 2 epoch / 10 epochs
#    0.10526 iters/sec. Estimated time to finish: 3 days, 5:46:27.643864.
#      total [############......................................] 25.21%
# this epoch [##########################........................] 52.10%
#       9900 iter, 2 epoch / 10 epochs
#    0.10519 iters/sec. Estimated time to finish: 3 days, 5:33:26.938905.
#      total [############......................................] 25.46%
# this epoch [###########################.......................] 54.65%
#      10000 iter, 2 epoch / 10 epochs
#    0.10511 iters/sec. Estimated time to finish: 3 days, 5:21:07.767863.
#      total [############......................................] 25.72%
# this epoch [############################......................] 57.19%
#      10100 iter, 2 epoch / 10 epochs
#    0.10505 iters/sec. Estimated time to finish: 3 days, 5:08:08.745014.
#      total [############......................................] 25.97%
# this epoch [#############################.....................] 59.74%
#      10200 iter, 2 epoch / 10 epochs
#    0.10499 iters/sec. Estimated time to finish: 3 days, 4:54:51.442173.
#      total [#############.....................................] 26.23%
# this epoch [###############################...................] 62.29%
#      10300 iter, 2 epoch / 10 epochs
#     0.1049 iters/sec. Estimated time to finish: 3 days, 4:42:49.505463.
#      total [#############.....................................] 26.48%
# this epoch [################################..................] 64.83%
#      10400 iter, 2 epoch / 10 epochs
#    0.10482 iters/sec. Estimated time to finish: 3 days, 4:30:37.761223.
#      total [#############.....................................] 26.74%
# this epoch [#################################.................] 67.38%
#      10500 iter, 2 epoch / 10 epochs
#    0.10471 iters/sec. Estimated time to finish: 3 days, 4:19:10.184917.
#      total [#############.....................................] 26.99%
# this epoch [##################################................] 69.92%
#      10600 iter, 2 epoch / 10 epochs
#    0.10465 iters/sec. Estimated time to finish: 3 days, 4:06:00.785933.
#      total [#############.....................................] 27.25%
# this epoch [####################################..............] 72.47%
#      10700 iter, 2 epoch / 10 epochs
#     0.1046 iters/sec. Estimated time to finish: 3 days, 3:52:04.830373.
#      total [#############.....................................] 27.50%
# this epoch [#####################################.............] 75.02%
#      10800 iter, 2 epoch / 10 epochs
#    0.10456 iters/sec. Estimated time to finish: 3 days, 3:38:01.318160.
#      total [#############.....................................] 27.76%
# this epoch [######################################............] 77.56%
#      10900 iter, 2 epoch / 10 epochs
#    0.10452 iters/sec. Estimated time to finish: 3 days, 3:23:59.955569.
#      total [##############....................................] 28.01%
# this epoch [########################################..........] 80.11%
#      11000 iter, 2 epoch / 10 epochs
#    0.10448 iters/sec. Estimated time to finish: 3 days, 3:09:50.466026.
#      total [##############....................................] 28.27%
# this epoch [#########################################.........] 82.66%
#      11100 iter, 2 epoch / 10 epochs
#    0.10444 iters/sec. Estimated time to finish: 3 days, 2:55:38.099848.
#      total [##############....................................] 28.52%
# this epoch [##########################################........] 85.20%
#      11200 iter, 2 epoch / 10 epochs
#     0.1044 iters/sec. Estimated time to finish: 3 days, 2:41:16.870248.
#      total [##############....................................] 28.77%
# this epoch [###########################################.......] 87.75%
#      11300 iter, 2 epoch / 10 epochs
#    0.10437 iters/sec. Estimated time to finish: 3 days, 2:26:43.511713.
#      total [##############....................................] 29.03%
# this epoch [#############################################.....] 90.30%
#      11400 iter, 2 epoch / 10 epochs
#    0.10433 iters/sec. Estimated time to finish: 3 days, 2:12:02.446975.
#      total [##############....................................] 29.28%
# this epoch [##############################################....] 92.84%
#      11500 iter, 2 epoch / 10 epochs
#    0.10431 iters/sec. Estimated time to finish: 3 days, 1:57:07.396937.
#      total [##############....................................] 29.54%
# this epoch [###############################################...] 95.39%
#      11600 iter, 2 epoch / 10 epochs
#    0.10429 iters/sec. Estimated time to finish: 3 days, 1:42:06.925528.
#      total [##############....................................] 29.79%
# this epoch [################################################..] 97.94%
#      11700 iter, 2 epoch / 10 epochs
#    0.10427 iters/sec. Estimated time to finish: 3 days, 1:26:55.387736.
# 3
#      total [###############...................................] 30.05%
# this epoch [..................................................]  0.48%
#      11800 iter, 3 epoch / 10 epochs
#    0.10425 iters/sec. Estimated time to finish: 3 days, 1:11:50.730312.
#      total [###############...................................] 30.30%
# this epoch [#.................................................]  3.03%
#      11900 iter, 3 epoch / 10 epochs
#    0.10423 iters/sec. Estimated time to finish: 3 days, 0:56:28.942813.
#      total [###############...................................] 30.56%
# this epoch [##................................................]  5.58%
#      12000 iter, 3 epoch / 10 epochs
#    0.10422 iters/sec. Estimated time to finish: 3 days, 0:41:08.770376.
#      total [###############...................................] 30.81%
# this epoch [####..............................................]  8.12%
#      12100 iter, 3 epoch / 10 epochs
#     0.1042 iters/sec. Estimated time to finish: 3 days, 0:25:46.796922.
#      total [###############...................................] 31.07%
# this epoch [#####.............................................] 10.67%
#      12200 iter, 3 epoch / 10 epochs
#    0.10417 iters/sec. Estimated time to finish: 3 days, 0:11:16.248400.
#      total [###############...................................] 31.32%
# this epoch [######............................................] 13.21%
#      12300 iter, 3 epoch / 10 epochs
#    0.10411 iters/sec. Estimated time to finish: 2 days, 23:57:47.204530.
#      total [###############...................................] 31.58%
# this epoch [#######...........................................] 15.76%
#      12400 iter, 3 epoch / 10 epochs
#    0.10405 iters/sec. Estimated time to finish: 2 days, 23:44:02.588152.
#      total [###############...................................] 31.83%
# this epoch [#########.........................................] 18.31%
#      12500 iter, 3 epoch / 10 epochs
#    0.10397 iters/sec. Estimated time to finish: 2 days, 23:31:12.280235.
#      total [################..................................] 32.09%
# this epoch [##########........................................] 20.85%
#      12600 iter, 3 epoch / 10 epochs
#    0.10391 iters/sec. Estimated time to finish: 2 days, 23:17:46.618197.
#      total [################..................................] 32.34%
# this epoch [###########.......................................] 23.40%
#      12700 iter, 3 epoch / 10 epochs
#    0.10386 iters/sec. Estimated time to finish: 2 days, 23:03:56.867606.
#      total [################..................................] 32.59%
# this epoch [############......................................] 25.95%
#      12800 iter, 3 epoch / 10 epochs
#    0.10378 iters/sec. Estimated time to finish: 2 days, 22:50:59.544260.
#      total [################..................................] 32.85%
# this epoch [##############....................................] 28.49%
#      12900 iter, 3 epoch / 10 epochs
#    0.10372 iters/sec. Estimated time to finish: 2 days, 22:37:34.215121.
#      total [################..................................] 33.10%
# this epoch [###############...................................] 31.04%
#      13000 iter, 3 epoch / 10 epochs
#    0.10366 iters/sec. Estimated time to finish: 2 days, 22:23:39.722227.
#      total [################..................................] 33.36%
# this epoch [################..................................] 33.59%
#      13100 iter, 3 epoch / 10 epochs
#    0.10359 iters/sec. Estimated time to finish: 2 days, 22:10:25.797470.
#      total [################..................................] 33.61%
# this epoch [##################................................] 36.13%
#      13200 iter, 3 epoch / 10 epochs
#    0.10354 iters/sec. Estimated time to finish: 2 days, 21:56:24.573345.
#      total [################..................................] 33.87%
# this epoch [###################...............................] 38.68%
#      13300 iter, 3 epoch / 10 epochs
#    0.10353 iters/sec. Estimated time to finish: 2 days, 21:40:45.707026.
#      total [#################.................................] 34.12%
# this epoch [####################..............................] 41.23%
#      13400 iter, 3 epoch / 10 epochs
#    0.10352 iters/sec. Estimated time to finish: 2 days, 21:25:06.904448.
#      total [#################.................................] 34.38%
# this epoch [#####################.............................] 43.77%
#      13500 iter, 3 epoch / 10 epochs
#    0.10351 iters/sec. Estimated time to finish: 2 days, 21:09:26.995331.
#      total [#################.................................] 34.63%
# this epoch [#######################...........................] 46.32%
#      13600 iter, 3 epoch / 10 epochs
#     0.1035 iters/sec. Estimated time to finish: 2 days, 20:53:42.698452.
#      total [#################.................................] 34.89%
# this epoch [########################..........................] 48.87%
#      13700 iter, 3 epoch / 10 epochs
#    0.10349 iters/sec. Estimated time to finish: 2 days, 20:37:56.871893.
#      total [#################.................................] 35.14%
# this epoch [#########################.........................] 51.41%
#      13800 iter, 3 epoch / 10 epochs
#    0.10348 iters/sec. Estimated time to finish: 2 days, 20:22:08.777374.
#      total [#################.................................] 35.40%
# this epoch [##########################........................] 53.96%
#      13900 iter, 3 epoch / 10 epochs
#    0.10348 iters/sec. Estimated time to finish: 2 days, 20:06:16.938800.
#      total [#################.................................] 35.65%
# this epoch [############################......................] 56.50%
#      14000 iter, 3 epoch / 10 epochs
#    0.10349 iters/sec. Estimated time to finish: 2 days, 19:49:32.999795.
#      total [#################.................................] 35.91%
# this epoch [#############################.....................] 59.05%
#      14100 iter, 3 epoch / 10 epochs
#    0.10349 iters/sec. Estimated time to finish: 2 days, 19:33:39.134496.
#      total [##################................................] 36.16%
# this epoch [##############################....................] 61.60%
#      14200 iter, 3 epoch / 10 epochs
#    0.10348 iters/sec. Estimated time to finish: 2 days, 19:17:54.214607.
#      total [##################................................] 36.41%
# this epoch [################################..................] 64.14%
#      14300 iter, 3 epoch / 10 epochs
#    0.10347 iters/sec. Estimated time to finish: 2 days, 19:02:08.990116.
#      total [##################................................] 36.67%
# this epoch [#################################.................] 66.69%
#      14400 iter, 3 epoch / 10 epochs
#    0.10346 iters/sec. Estimated time to finish: 2 days, 18:46:35.044106.
#      total [##################................................] 36.92%
# this epoch [##################################................] 69.24%
#      14500 iter, 3 epoch / 10 epochs
#    0.10344 iters/sec. Estimated time to finish: 2 days, 18:30:56.278069.
#      total [##################................................] 37.18%
# this epoch [###################################...............] 71.78%
#      14600 iter, 3 epoch / 10 epochs
#    0.10343 iters/sec. Estimated time to finish: 2 days, 18:15:11.527428.
#      total [##################................................] 37.43%
# this epoch [#####################################.............] 74.33%
#      14700 iter, 3 epoch / 10 epochs
#    0.10342 iters/sec. Estimated time to finish: 2 days, 17:59:29.478706.
#      total [##################................................] 37.69%
# this epoch [######################################............] 76.88%
#      14800 iter, 3 epoch / 10 epochs
#    0.10341 iters/sec. Estimated time to finish: 2 days, 17:43:58.662816.
#      total [##################................................] 37.94%
# this epoch [#######################################...........] 79.42%
#      14900 iter, 3 epoch / 10 epochs
#    0.10339 iters/sec. Estimated time to finish: 2 days, 17:28:26.585319.
#      total [###################...............................] 38.20%
# this epoch [########################################..........] 81.97%
#      15000 iter, 3 epoch / 10 epochs
#    0.10338 iters/sec. Estimated time to finish: 2 days, 17:12:53.590724.
#      total [###################...............................] 38.45%
# this epoch [##########################################........] 84.52%
#      15100 iter, 3 epoch / 10 epochs
#    0.10336 iters/sec. Estimated time to finish: 2 days, 16:57:20.046253.
#      total [###################...............................] 38.71%
# this epoch [###########################################.......] 87.06%
#      15200 iter, 3 epoch / 10 epochs
#    0.10334 iters/sec. Estimated time to finish: 2 days, 16:41:52.587573.
#      total [###################...............................] 38.96%
# this epoch [############################################......] 89.61%
#      15300 iter, 3 epoch / 10 epochs
#    0.10333 iters/sec. Estimated time to finish: 2 days, 16:26:25.491116.
#      total [###################...............................] 39.22%
# this epoch [##############################################....] 92.15%
#      15400 iter, 3 epoch / 10 epochs
#    0.10331 iters/sec. Estimated time to finish: 2 days, 16:10:58.061802.
#      total [###################...............................] 39.47%
# this epoch [###############################################...] 94.70%
#      15500 iter, 3 epoch / 10 epochs
#    0.10329 iters/sec. Estimated time to finish: 2 days, 15:55:20.577751.
#      total [###################...............................] 39.72%
# this epoch [################################################..] 97.25%
#      15600 iter, 3 epoch / 10 epochs
#    0.10329 iters/sec. Estimated time to finish: 2 days, 15:39:23.562773.
#      total [###################...............................] 39.98%
# this epoch [#################################################.] 99.79%
#      15700 iter, 3 epoch / 10 epochs
#    0.10333 iters/sec. Estimated time to finish: 2 days, 15:21:57.104820.
# 4
#      total [####################..............................] 40.23%
# this epoch [#.................................................]  2.34%
#      15800 iter, 4 epoch / 10 epochs
#    0.10336 iters/sec. Estimated time to finish: 2 days, 15:04:29.234095.
#      total [####################..............................] 40.49%
# this epoch [##................................................]  4.89%
#      15900 iter, 4 epoch / 10 epochs
#    0.10342 iters/sec. Estimated time to finish: 2 days, 14:46:24.256041.
#      total [####################..............................] 40.74%
# this epoch [###...............................................]  7.43%
#      16000 iter, 4 epoch / 10 epochs
#    0.10342 iters/sec. Estimated time to finish: 2 days, 14:29:59.129087.
#      total [####################..............................] 41.00%
# this epoch [####..............................................]  9.98%
#      16100 iter, 4 epoch / 10 epochs
#    0.10341 iters/sec. Estimated time to finish: 2 days, 14:14:23.898054.
#      total [####################..............................] 41.25%
# this epoch [######............................................] 12.53%
#      16200 iter, 4 epoch / 10 epochs
#     0.1034 iters/sec. Estimated time to finish: 2 days, 13:58:42.224564.
#      total [####################..............................] 41.51%
# this epoch [#######...........................................] 15.07%
#      16300 iter, 4 epoch / 10 epochs
#    0.10338 iters/sec. Estimated time to finish: 2 days, 13:43:03.034650.
#      total [####################..............................] 41.76%
# this epoch [########..........................................] 17.62%
#      16400 iter, 4 epoch / 10 epochs
#    0.10338 iters/sec. Estimated time to finish: 2 days, 13:27:12.218146.
#      total [#####################.............................] 42.02%
# this epoch [##########........................................] 20.17%
#      16500 iter, 4 epoch / 10 epochs
#    0.10336 iters/sec. Estimated time to finish: 2 days, 13:11:31.603849.
#      total [#####################.............................] 42.27%
# this epoch [###########.......................................] 22.71%
#      16600 iter, 4 epoch / 10 epochs
#    0.10336 iters/sec. Estimated time to finish: 2 days, 12:55:42.533804.
#      total [#####################.............................] 42.53%
# this epoch [############......................................] 25.26%
#      16700 iter, 4 epoch / 10 epochs
#    0.10335 iters/sec. Estimated time to finish: 2 days, 12:39:50.947865.
#      total [#####################.............................] 42.78%
# this epoch [#############.....................................] 27.81%
#      16800 iter, 4 epoch / 10 epochs
#    0.10334 iters/sec. Estimated time to finish: 2 days, 12:23:57.335896.
#      total [#####################.............................] 43.04%
# this epoch [###############...................................] 30.35%
#      16900 iter, 4 epoch / 10 epochs
#    0.10334 iters/sec. Estimated time to finish: 2 days, 12:08:02.218985.
#      total [#####################.............................] 43.29%
# this epoch [################..................................] 32.90%
#      17000 iter, 4 epoch / 10 epochs
#    0.10333 iters/sec. Estimated time to finish: 2 days, 11:52:08.038883.
#      total [#####################.............................] 43.54%
# this epoch [#################.................................] 35.44%
#      17100 iter, 4 epoch / 10 epochs
#    0.10332 iters/sec. Estimated time to finish: 2 days, 11:36:11.989589.
#      total [#####################.............................] 43.80%
# this epoch [##################................................] 37.99%
#      17200 iter, 4 epoch / 10 epochs
#    0.10332 iters/sec. Estimated time to finish: 2 days, 11:20:09.924278.
#      total [######################............................] 44.05%
# this epoch [####################..............................] 40.54%
#      17300 iter, 4 epoch / 10 epochs
#    0.10332 iters/sec. Estimated time to finish: 2 days, 11:04:01.371432.
#      total [######################............................] 44.31%
# this epoch [#####################.............................] 43.08%
#      17400 iter, 4 epoch / 10 epochs
#    0.10332 iters/sec. Estimated time to finish: 2 days, 10:48:02.604060.
#      total [######################............................] 44.56%
# this epoch [######################............................] 45.63%
#      17500 iter, 4 epoch / 10 epochs
#    0.10331 iters/sec. Estimated time to finish: 2 days, 10:32:01.907578.
#      total [######################............................] 44.82%
# this epoch [########################..........................] 48.18%
#      17600 iter, 4 epoch / 10 epochs
#    0.10331 iters/sec. Estimated time to finish: 2 days, 10:15:57.694732.
#      total [######################............................] 45.07%
# this epoch [#########################.........................] 50.72%
#      17700 iter, 4 epoch / 10 epochs
#    0.10331 iters/sec. Estimated time to finish: 2 days, 9:59:55.584059.
#      total [######################............................] 45.33%
# this epoch [##########################........................] 53.27%
#      17800 iter, 4 epoch / 10 epochs
#     0.1033 iters/sec. Estimated time to finish: 2 days, 9:43:57.905230.
#      total [######################............................] 45.58%
# this epoch [###########################.......................] 55.82%
#      17900 iter, 4 epoch / 10 epochs
#     0.1033 iters/sec. Estimated time to finish: 2 days, 9:28:00.853799.
#      total [######################............................] 45.84%
# this epoch [#############################.....................] 58.36%
#      18000 iter, 4 epoch / 10 epochs
#    0.10329 iters/sec. Estimated time to finish: 2 days, 9:12:12.130760.
#      total [#######################...........................] 46.09%
# this epoch [##############################....................] 60.91%
#      18100 iter, 4 epoch / 10 epochs
#    0.10328 iters/sec. Estimated time to finish: 2 days, 8:56:18.891569.
#      total [#######################...........................] 46.35%
# this epoch [###############################...................] 63.46%
#      18200 iter, 4 epoch / 10 epochs
#    0.10328 iters/sec. Estimated time to finish: 2 days, 8:40:15.312372.
#      total [#######################...........................] 46.60%
# this epoch [#################################.................] 66.00%
#      18300 iter, 4 epoch / 10 epochs
#    0.10327 iters/sec. Estimated time to finish: 2 days, 8:24:14.745471.
#      total [#######################...........................] 46.85%
# this epoch [##################################................] 68.55%
#      18400 iter, 4 epoch / 10 epochs
#    0.10327 iters/sec. Estimated time to finish: 2 days, 8:08:19.857449.
#      total [#######################...........................] 47.11%
# this epoch [###################################...............] 71.10%
#      18500 iter, 4 epoch / 10 epochs
#    0.10326 iters/sec. Estimated time to finish: 2 days, 7:52:16.829471.
#      total [#######################...........................] 47.36%
# this epoch [####################################..............] 73.64%
#      18600 iter, 4 epoch / 10 epochs
#    0.10326 iters/sec. Estimated time to finish: 2 days, 7:36:14.166695.
#      total [#######################...........................] 47.62%
# this epoch [######################################............] 76.19%
#      18700 iter, 4 epoch / 10 epochs
#    0.10326 iters/sec. Estimated time to finish: 2 days, 7:20:09.552769.
#      total [#######################...........................] 47.87%
# this epoch [#######################################...........] 78.73%
#      18800 iter, 4 epoch / 10 epochs
#    0.10323 iters/sec. Estimated time to finish: 2 days, 7:04:55.546944.
#      total [########################..........................] 48.13%
# this epoch [########################################..........] 81.28%
#      18900 iter, 4 epoch / 10 epochs
#    0.10323 iters/sec. Estimated time to finish: 2 days, 6:48:50.149755.
#      total [########################..........................] 48.38%
# this epoch [#########################################.........] 83.83%
#      19000 iter, 4 epoch / 10 epochs
#    0.10323 iters/sec. Estimated time to finish: 2 days, 6:32:48.597278.
#      total [########################..........................] 48.64%
# this epoch [###########################################.......] 86.37%
#      19100 iter, 4 epoch / 10 epochs
#    0.10323 iters/sec. Estimated time to finish: 2 days, 6:16:39.162411.
#      total [########################..........................] 48.89%
# this epoch [############################################......] 88.92%
#      19200 iter, 4 epoch / 10 epochs
#    0.10322 iters/sec. Estimated time to finish: 2 days, 6:00:36.483597.
#      total [########################..........................] 49.15%
# this epoch [#############################################.....] 91.47%
#      19300 iter, 4 epoch / 10 epochs
#    0.10322 iters/sec. Estimated time to finish: 2 days, 5:44:35.080804.
#      total [########################..........................] 49.40%
# this epoch [###############################################...] 94.01%
#      19400 iter, 4 epoch / 10 epochs
#    0.10322 iters/sec. Estimated time to finish: 2 days, 5:28:30.057706.
#      total [########################..........................] 49.66%
# this epoch [################################################..] 96.56%
#      19500 iter, 4 epoch / 10 epochs
#    0.10321 iters/sec. Estimated time to finish: 2 days, 5:12:28.238228.
#      total [########################..........................] 49.91%
# this epoch [#################################################.] 99.11%
#      19600 iter, 4 epoch / 10 epochs
#    0.10321 iters/sec. Estimated time to finish: 2 days, 4:56:23.603449.
# 5
#      total [#########################.........................] 50.17%
# this epoch [..................................................]  1.65%
#      19700 iter, 5 epoch / 10 epochs
#    0.10321 iters/sec. Estimated time to finish: 2 days, 4:40:20.271335.
#      total [#########################.........................] 50.42%
# this epoch [##................................................]  4.20%
#      19800 iter, 5 epoch / 10 epochs
#    0.10324 iters/sec. Estimated time to finish: 2 days, 4:23:18.608052.
#      total [#########################.........................] 50.67%
# this epoch [###...............................................]  6.75%
#      19900 iter, 5 epoch / 10 epochs
#    0.10329 iters/sec. Estimated time to finish: 2 days, 4:05:39.319004.
#      total [#########################.........................] 50.93%
# this epoch [####..............................................]  9.29%
#      20000 iter, 5 epoch / 10 epochs
#    0.10335 iters/sec. Estimated time to finish: 2 days, 3:47:29.452729.
#      total [#########################.........................] 51.18%
# this epoch [#####.............................................] 11.84%
#      20100 iter, 5 epoch / 10 epochs
#    0.10341 iters/sec. Estimated time to finish: 2 days, 3:29:43.600956.
#      total [#########################.........................] 51.44%
# this epoch [#######...........................................] 14.38%
#      20200 iter, 5 epoch / 10 epochs
#    0.10346 iters/sec. Estimated time to finish: 2 days, 3:12:07.013418.
#      total [#########################.........................] 51.69%
# this epoch [########..........................................] 16.93%
#      20300 iter, 5 epoch / 10 epochs
#     0.1035 iters/sec. Estimated time to finish: 2 days, 2:54:51.935885.
#      total [#########################.........................] 51.95%
# this epoch [#########.........................................] 19.48%
#      20400 iter, 5 epoch / 10 epochs
#    0.10353 iters/sec. Estimated time to finish: 2 days, 2:37:43.427571.
#      total [##########################........................] 52.20%
# this epoch [###########.......................................] 22.02%
#      20500 iter, 5 epoch / 10 epochs
#    0.10358 iters/sec. Estimated time to finish: 2 days, 2:20:06.522890.
#      total [##########################........................] 52.46%
# this epoch [############......................................] 24.57%
#      20600 iter, 5 epoch / 10 epochs
#     0.1036 iters/sec. Estimated time to finish: 2 days, 2:03:33.573282.
#      total [##########################........................] 52.71%
# this epoch [#############.....................................] 27.12%
#      20700 iter, 5 epoch / 10 epochs
#     0.1036 iters/sec. Estimated time to finish: 2 days, 1:47:32.275670.
#      total [##########################........................] 52.97%
# this epoch [##############....................................] 29.66%
#      20800 iter, 5 epoch / 10 epochs
#     0.1036 iters/sec. Estimated time to finish: 2 days, 1:31:29.917842.
#      total [##########################........................] 53.22%
# this epoch [################..................................] 32.21%
#      20900 iter, 5 epoch / 10 epochs
#     0.1036 iters/sec. Estimated time to finish: 2 days, 1:15:23.378026.
#      total [##########################........................] 53.48%
# this epoch [#################.................................] 34.76%
#      21000 iter, 5 epoch / 10 epochs
#     0.1036 iters/sec. Estimated time to finish: 2 days, 0:59:20.422189.
#      total [##########################........................] 53.73%
# this epoch [##################................................] 37.30%
#      21100 iter, 5 epoch / 10 epochs
#    0.10359 iters/sec. Estimated time to finish: 2 days, 0:43:18.102572.
#      total [##########################........................] 53.98%
# this epoch [###################...............................] 39.85%
#      21200 iter, 5 epoch / 10 epochs
#    0.10359 iters/sec. Estimated time to finish: 2 days, 0:27:12.341529.
#      total [###########################.......................] 54.24%
# this epoch [#####################.............................] 42.40%
#      21300 iter, 5 epoch / 10 epochs
#    0.10359 iters/sec. Estimated time to finish: 2 days, 0:11:09.999624.
#      total [###########################.......................] 54.49%
# this epoch [######################............................] 44.94%
#      21400 iter, 5 epoch / 10 epochs
#    0.10359 iters/sec. Estimated time to finish: 1 day, 23:55:08.683113.

# %% [markdown]
# #
#
#
# * Compute micro, macro, and class-wise f1s
# * Report training and validation metrics
# * Report activation histograms
# * Report activation variances
# * Report gradient histograms
# * Report gradient variances
# * Checkpoint model every X min
#
# Need to be able to:
# * Run experiments but exchange architectures
# * Reproduce all experiments
# * Analyze results, diagnose optimization and data errors

# %%
cat result/log
